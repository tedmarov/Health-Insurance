# %%
import pandas as pd
df = pd.read_csv('./Documents/Health Coverage 2021-2022.csv', names = ["Health Coverage 2021-2022"], skiprows=[0, 1, 2, 3, 4, 5, 6], header=None, encoding="utf-8", na_filter=False)
pd.set_option('display.max_rows', None)
df.head(78)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Health Coverage 2021-2022
# ...

# %%
import pandas as pd

df = pd.read_csv('./Documents/Health Characteristics 2021-2022.csv', names = ["Health Characteristics 2021-2022"], skiprows=[0, 1, 2, 3, 4], header=None, encoding="utf-8", na_filter=False)
pd.set_option('display.max_rows', None)
df.head(78)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Health Characteristics 2021-2022
# Characteristic                                                                                                                                                                                                                                                                                                                                                           Total
# ...

# %%
import pandas as pd

df = pd.read_csv('./Documents/Health Households 2021-2022.csv', names = ['Household Characteristics 2021-2022'], skiprows=[0, 1, 2, 3, 4], header=None, encoding="utf-8", na_filter=False)
pd.set_option('display.max_rows', None)
df.head(78)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Household Characteristics 2021-2022
# Household                                                                                                                                                                                                                                                                                                                                                               Total
# ...
